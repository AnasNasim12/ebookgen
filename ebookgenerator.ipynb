# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasNasim12/ebookgen/blob/main/ebookgenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
generation_config = {
    "temperature":0.9,
    "top_p":1.0,
    "top_k":1,
    "max_output_tokens":2048
}


safety_settings = [
    {
        "category": "HARM_CATEGORY_DANGEROUS",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE",
    },
]

# %%
import google.generativeai as genai
import json

genai.configure(api_key='AIzaSyCjis36JPZtvnxavK8gIks0nRw6BaBkdRA')

model = genai.GenerativeModel('gemini-pro')
title="Norse Mythology"
topic="Aesir vs vanir rivalry"
target_audience="Teenagers"
num_chapters = 10
num_subsections = 4
outline_prompt = (
    f'We are writing an eBook called "{title}". It is about'
    f' "{topic}". Our reader is: {target_audience}". Create'
    " a compehensive outline for our ebook, which will have"
    f" {num_chapters} chapter(s). Each chapter should have exactly"
    f" {num_subsections} subsection(s)"
    f'Output format for prompt:'
    f'python dict with key: chapter title, value: a single list/array Please refrain from adding any unnecessary formatting elements like code blocks or indentation in the output.'
    f'Containing subsection titles within the chapter (the subtopics should be inside the list)'
)
#we have to use response.text to get the text from the response.
response = model.generate_content(outline_prompt)
print(response.text)
# Out:
# {
#  "Chapter 1: Introduction to Norse Mythology": [
#   "Origins and Beliefs of Norse Mythology",
#   "The Nine Realms and the World Tree",
#   "The Aesir and Vanir Gods",
#   "The Rivalry Begins: Causes and Tensions"
#  ],
#  "Chapter 2: The Aesir Gods": [
#   "Odin: The All-Father and God of Wisdom",
#   "Thor: The God of Thunder and Lightning",
#   "Loki: The Trickster and God of Mischief",
#   "Freyja: The Goddess of Love, Beauty, and Fertility"
#  ],
#  "Chapter 3: The Vanir Gods": [
#   "Njörðr: The God of the Sea, Wind, and Fire",
#   "Freyr: The God of Fertility, Peace, and Prosperity",
#   "Freya: The Goddess of Love, Fertility, and Magic",
#   "Kvasir: The God of Wisdom and Poetry"
#  ],
#  "Chapter 4: The Rivalry Escalates": [
#   "The Battle of the Gods: Aesir vs. Vanir",
#   "The Truce and Exchange of Hostages",
#   "The Marriage of Freyr and Gerðr",
#   "The Theft of Idunn's Apples"
#  ],
#  "Chapter 5: The Rise of Loki": [
#   "Loki's Trickery and Misdeeds",
#   "The Death of Baldr: Loki's Ultimate Betrayal",
#   "Loki's Punishment and Imprisonment",
#   "The Prophecy of Ragnarök"
#  ],
#  "Chapter 6: The Prophesied End": [
#   "The Coming of Ragnarök: The Twilight of the Gods",
#   "The Battle of Vigrid: The Final Conflict",
#   "The Rebirth of the World and the New Age",
#   "The Legacy of Norse Mythology"
#  ],
#  "Chapter 7: The Aesir and Vanir in Popular Culture": [
#   "Norse Mythology in Literature and Art",
#   "The Influence on Modern Comics and Films",
#   "The Revival of Norse Mythology in Contemporary Society",
#   "The Enduring Appeal of the Aesir and Vanir"
#  ],
#  "Chapter 8: The Symbolism and Meaning": [
#   "The Aesir and Vanir as Archetypal Figures",
#   "The Rivalry as a Reflection of Human Nature",
#   "The Importance of Balance and Harmony",
#   "The Lessons Learned from Norse Mythology"
#  ],
#  "Chapter 9: The Aesir and Vanir in Modern Spirituality": [
#   "Heathenry and the Revival of Norse Religion",
#   "The Use of Norse Mythology in Personal Growth",
#   "The Relevance of Norse Myths for Contemporary Spirituality",
#   "Finding Inspiration in the Aesir and Vanir"
#  ],
#  "Chapter 10: Conclusion: The Timeless Legacy": [
#   "The Enduring Impact of Norse Mythology",
#   "The Aesir and Vanir as Symbols of Strength and Resilience",
#   "The Importance of Preserving and Studying Norse Myths",
#   "The Future of Norse Mythology"
#  ]
# }

# %%
pip install markdown weasyprint PyPDF2
# Out:
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (3.6)
# Collecting weasyprint
#   Downloading weasyprint-61.2-py3-none-any.whl (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 kB 6.1 MB/s eta 0:00:00
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 11.3 MB/s eta 0:00:00
# Collecting pydyf>=0.8.0 (from weasyprint)
#   Downloading pydyf-0.9.0-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.10/dist-packages (from weasyprint) (1.16.0)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from weasyprint) (1.1)
# Requirement already satisfied: tinycss2>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint) (1.2.1)
# Collecting cssselect2>=0.1 (from weasyprint)
#   Downloading cssselect2-0.7.0-py3-none-any.whl (15 kB)
# Collecting Pyphen>=0.9.1 (from weasyprint)
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=9.1.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint) (9.4.0)
# Requirement already satisfied: fonttools[woff]>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from weasyprint) (4.50.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=0.6->weasyprint) (2.21)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from cssselect2>=0.1->weasyprint) (0.5.1)
# Collecting zopfli>=0.1.4 (from fonttools[woff]>=4.0.0->weasyprint)
#   Downloading zopfli-0.2.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (848 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.9/848.9 kB 32.6 MB/s eta 0:00:00
# Collecting brotli>=1.0.1 (from fonttools[woff]>=4.0.0->weasyprint)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 45.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->weasyprint) (1.16.0)
# Installing collected packages: brotli, zopfli, Pyphen, PyPDF2, pydyf, cssselect2, weasyprint
# Successfully installed PyPDF2-3.0.1 Pyphen-0.14.0 brotli-1.1.0 cssselect2-0.7.0 pydyf-0.9.0 weasyprint-61.2 zopfli-0.2.3

# %%
x = response.text

# %%
try:
    dictionary = json.loads(response.text)
    print("Successfully converted string to dictionary:", dictionary)
except json.JSONDecodeError:
    print("Error: String is not valid JSON data.")
# Out:
# Successfully converted string to dictionary: {'Chapter 1: Introduction to Norse Mythology': ['Origins and Beliefs of Norse Mythology', 'The Nine Realms and the World Tree', 'The Aesir and Vanir Gods', 'The Rivalry Begins: Causes and Tensions'], 'Chapter 2: The Aesir Gods': ['Odin: The All-Father and God of Wisdom', 'Thor: The God of Thunder and Lightning', 'Loki: The Trickster and God of Mischief', 'Freyja: The Goddess of Love, Beauty, and Fertility'], 'Chapter 3: The Vanir Gods': ['Njörðr: The God of the Sea, Wind, and Fire', 'Freyr: The God of Fertility, Peace, and Prosperity', 'Freya: The Goddess of Love, Fertility, and Magic', 'Kvasir: The God of Wisdom and Poetry'], 'Chapter 4: The Rivalry Escalates': ['The Battle of the Gods: Aesir vs. Vanir', 'The Truce and Exchange of Hostages', 'The Marriage of Freyr and Gerðr', "The Theft of Idunn's Apples"], 'Chapter 5: The Rise of Loki': ["Loki's Trickery and Misdeeds", "The Death of Baldr: Loki's Ultimate Betrayal", "Loki's Punishment and Imprisonment", 'The Prophecy of Ragnarök'], 'Chapter 6: The Prophesied End': ['The Coming of Ragnarök: The Twilight of the Gods', 'The Battle of Vigrid: The Final Conflict', 'The Rebirth of the World and the New Age', 'The Legacy of Norse Mythology'], 'Chapter 7: The Aesir and Vanir in Popular Culture': ['Norse Mythology in Literature and Art', 'The Influence on Modern Comics and Films', 'The Revival of Norse Mythology in Contemporary Society', 'The Enduring Appeal of the Aesir and Vanir'], 'Chapter 8: The Symbolism and Meaning': ['The Aesir and Vanir as Archetypal Figures', 'The Rivalry as a Reflection of Human Nature', 'The Importance of Balance and Harmony', 'The Lessons Learned from Norse Mythology'], 'Chapter 9: The Aesir and Vanir in Modern Spirituality': ['Heathenry and the Revival of Norse Religion', 'The Use of Norse Mythology in Personal Growth', 'The Relevance of Norse Myths for Contemporary Spirituality', 'Finding Inspiration in the Aesir and Vanir'], 'Chapter 10: Conclusion: The Timeless Legacy': ['The Enduring Impact of Norse Mythology', 'The Aesir and Vanir as Symbols of Strength and Resilience', 'The Importance of Preserving and Studying Norse Myths', 'The Future of Norse Mythology']}

# %%
dictionary

# %%
def get_all_subtopics(dictionary):
  all_subtopics = []
  for chapter, subtopics in dictionary.items():
    all_subtopics.extend(subtopics)  # Add subtopics to the list

    if isinstance(subtopics, dict):
      all_subtopics.extend(get_all_subtopics(subtopics))  # Recursive call for nested chapters
  return all_subtopics
# Initialize!
all_subtopics = get_all_subtopics(dictionary)
print(all_subtopics)
# Out:
# ['Origins of the Aesir and Vanir', 'Clash of Cultures and Beliefs', 'Early Conflicts and Tensions', 'The Brewing Storm', 'Prelude to the Battle', 'The Opening Salvos', 'Major Battles and Turning Points', 'The Ceasefire and Reconciliation', 'Njörðr, the God of Wind and Sea', 'Freyr, the God of Fertility', 'Freyja, the Goddess of Love and Magic', 'Kvasir, the God of Wisdom and Inspiration', 'Odin, the All-Father', 'Thor, the God of Thunder', 'Loki, the Trickster God', 'Heimdallr, the Guardian of Asgard', 'The Challenge of Freya', 'The Choice of Champions', 'The Duel Between Heimdallr and Loki', 'The Outcome and Significance', 'The Lay of Thrym', 'The Curse of Andvari', 'The Apples of Idunn', 'The Binding of Loki', 'The Exchange of Hostages', 'The Rise of Freyr and Freyja in Asgard', 'The Renewal of the Alliance', 'The Legacy of the Conflict', 'Divine Inspiration for Warfare', 'Religious Beliefs and Practices', 'Social Hierarchy and Kinship', 'Art and Literature', 'Depictions in Literature and Art', 'Influence on Fantasy and Role-Playing Games', 'Contemporary Interpretations and Retellings', 'The Enduring Appeal of the Myth', 'Summary of the Aesir-Vanir Rivalry', 'Its Impact on Norse Mythology and Culture', 'The Legacy and Relevance of the Myth', 'Call to Action for Further Exploration']

# %%
# index page
def print_contents(dictionary):
  for chapter, subtopics in dictionary.items():
    print(f"## {chapter}")  # Print chapter title as H2 heading
    for subtopic in subtopics:
      print(f"- #### {subtopic}")  # Print subtopic as list item

print_contents(dictionary)
# Out:
# ## Chapter 1: The Roots of Rivalry
# - #### Origins of the Aesir and Vanir
# - #### Clash of Cultures and Beliefs
# - #### Early Conflicts and Tensions
# - #### The Brewing Storm
# ## Chapter 2: The War of the Gods
# - #### Prelude to the Battle
# - #### The Opening Salvos
# - #### Major Battles and Turning Points
# - #### The Ceasefire and Reconciliation
# ## Chapter 3: The Vanir Gods
# - #### Njörðr, the God of Wind and Sea
# - #### Freyr, the God of Fertility
# - #### Freyja, the Goddess of Love and Magic
# - #### Kvasir, the God of Wisdom and Inspiration
# ## Chapter 4: The Aesir Gods
# - #### Odin, the All-Father
# - #### Thor, the God of Thunder
# - #### Loki, the Trickster God
# - #### Heimdallr, the Guardian of Asgard
# ## Chapter 5: The Battle of the Champions
# - #### The Challenge of Freya
# - #### The Choice of Champions
# - #### The Duel Between Heimdallr and Loki
# - #### The Outcome and Significance
# ## Chapter 6: Myths and Legends of the Rivalry
# - #### The Lay of Thrym
# - #### The Curse of Andvari
# - #### The Apples of Idunn
# - #### The Binding of Loki
# ## Chapter 7: The Aftermath of the War
# - #### The Exchange of Hostages
# - #### The Rise of Freyr and Freyja in Asgard
# - #### The Renewal of the Alliance
# - #### The Legacy of the Conflict
# ## Chapter 8: The Influence on Viking Culture
# - #### Divine Inspiration for Warfare
# - #### Religious Beliefs and Practices
# - #### Social Hierarchy and Kinship
# - #### Art and Literature
# ## Chapter 9: The Aesir-Vanir Rivalry in Modern Culture
# - #### Depictions in Literature and Art
# - #### Influence on Fantasy and Role-Playing Games
# - #### Contemporary Interpretations and Retellings
# - #### The Enduring Appeal of the Myth
# ## Chapter 10: Conclusion
# - #### Summary of the Aesir-Vanir Rivalry
# - #### Its Impact on Norse Mythology and Culture
# - #### The Legacy and Relevance of the Myth
# - #### Call to Action for Further Exploration

# %%
def print_contents_to_file(dictionary, filename):
  """Prints the contents of the dictionary to a text file with appropriate formatting."""
  with open(filename, 'w') as file:
    for chapter, subtopics in dictionary.items():
      file.write(f"## {chapter}\n")  # Write chapter title with newline
      for subtopic in subtopics:
        file.write(f"- #### {subtopic}\n")  # Write subtopic with newline

# Example usage (replace `your_dictionary` with your actual dictionary

print_contents_to_file(dictionary, "contents.md")

# %%
import markdown
from weasyprint import HTML
import os

# Replace 'your_file.md' with the path to your Markdown file
markdown_file_path = 'contents.md'
pdf_file_path = 'contents.pdf'

# Read the Markdown file
with open(markdown_file_path, 'r', encoding='utf-8') as md_file:
    markdown_text = md_file.read()

# Convert Markdown to HTML
html_text = markdown.markdown(markdown_text)

# Convert HTML to PDF and save the PDF file
HTML(string=html_text).write_pdf(pdf_file_path)

print(f'PDF has been generated: {pdf_file_path}')
# Out:
# PDF has been generated: contents.pdf

# %%
all_subtopics
# Out:
# ['Origins of the Aesir and Vanir',
#  'Clash of Cultures and Beliefs',
#  'Early Conflicts and Tensions',
#  'The Brewing Storm',
#  'Prelude to the Battle',
#  'The Opening Salvos',
#  'Major Battles and Turning Points',
#  'The Ceasefire and Reconciliation',
#  'Njörðr, the God of Wind and Sea',
#  'Freyr, the God of Fertility',
#  'Freyja, the Goddess of Love and Magic',
#  'Kvasir, the God of Wisdom and Inspiration',
#  'Odin, the All-Father',
#  'Thor, the God of Thunder',
#  'Loki, the Trickster God',
#  'Heimdallr, the Guardian of Asgard',
#  'The Challenge of Freya',
#  'The Choice of Champions',
#  'The Duel Between Heimdallr and Loki',
#  'The Outcome and Significance',
#  'The Lay of Thrym',
#  'The Curse of Andvari',
#  'The Apples of Idunn',
#  'The Binding of Loki',
#  'The Exchange of Hostages',
#  'The Rise of Freyr and Freyja in Asgard',
#  'The Renewal of the Alliance',
#  'The Legacy of the Conflict',
#  'Divine Inspiration for Warfare',
#  'Religious Beliefs and Practices',
#  'Social Hierarchy and Kinship',
#  'Art and Literature',
#  'Depictions in Literature and Art',
#  'Influence on Fantasy and Role-Playing Games',
#  'Contemporary Interpretations and Retellings',
#  'The Enduring Appeal of the Myth',
#  'Summary of the Aesir-Vanir Rivalry',
#  'Its Impact on Norse Mythology and Culture',
#  'The Legacy and Relevance of the Myth',
#  'Call to Action for Further Exploration']

# %%
type(all_subtopics)
# Out:
# list

# %%
type(dictionary)
# Out:
# dict

# %%
# here's the magic
page_prompt = (
    f'We are writing an eBook called "{title}". It is about'
    f' "{topic}". Our reader is: {target_audience}".'
    f'You will be given a topic and you must generate detailed text of atleast 400 words, keeping in mind the topic {topic} and target audience {target_audience}'
    f'Output format for prompt:'
    f'Detailed text, nuanced text, informative. Keep the output as long as possible. Make sure you follow proper markdown formatting for headings and such. In case of code snippets, keep proper markdown formatting'
    f'It is of utmost importance that the formatting is right!'
    f'Imagine you are writing a page for the book, your text should be written in a way that the target audience understands it with ease. Make sure that the content you generate is continuous and cohesive'
    f'So in case you are writing a story, you must maintain continuity. Stories do not need a conclusion section.'
    f'Topic is as follows:'
)
all_text = ""
if all_subtopics is not None:
  for subtopic in all_subtopics:
      page = model.generate_content(page_prompt + subtopic, safety_settings=safety_settings)
      all_text += page.text + "\n\n"
  with open("ebook.md", "a") as f:
    f.write(all_text)
else:
    print("Chapter not found in the dictionary.")

# %%
import markdown
from weasyprint import HTML
import os

# Replace 'your_file.md' with the path to your Markdown file
markdown_file_path = 'ebook.md'
pdf_file_path = 'ebook.pdf'

# Read the Markdown file
with open(markdown_file_path, 'r', encoding='utf-8') as md_file:
    markdown_text = md_file.read()

# Convert Markdown to HTML
html_text = markdown.markdown(markdown_text)

# Convert HTML to PDF and save the PDF file
HTML(string=html_text).write_pdf(pdf_file_path)

print(f'PDF has been generated: {pdf_file_path}')
# Out:
# PDF has been generated: ebook.pdf

# %%
import PyPDF2

# File paths
contents_file_path = 'contents.pdf'
ebook_file_path = 'ebook.pdf'
merged_file_path = 'merged_ebook.pdf'

# Open the PDF files
with open(contents_file_path, 'rb') as contents_file, open(ebook_file_path, 'rb') as ebook_file:
    # Create PDF reader objects for each file
    contents_reader = PyPDF2.PdfReader(contents_file)
    ebook_reader = PyPDF2.PdfReader(ebook_file)

    # Create a PDF writer object for the output file
    pdf_writer = PyPDF2.PdfWriter()

    # Add all pages from the contents PDF
    for page_num in range(len(contents_reader.pages)):
        page = contents_reader.pages[page_num]
        pdf_writer.add_page(page)

    # Add all pages from the ebook PDF
    for page_num in range(len(ebook_reader.pages)):
        page = ebook_reader.pages[page_num]
        pdf_writer.add_page(page)

    # Write to a new PDF file
    with open(merged_file_path, 'wb') as merged_file:
        pdf_writer.write(merged_file)

print(f'PDF files have been merged into {merged_file_path}')
# Out:
# PDF files have been merged into merged_ebook.pdf

# %%
pip install -U diffusers accelerate transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 44.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 92.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.7 MB/s eta 0:00:00

# %%
pip install Pillow reportlab
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Collecting reportlab
#   Downloading reportlab-4.1.0-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from reportlab) (5.2.0)
# Installing collected packages: reportlab
# Successfully installed reportlab-4.1.0

# %%
import torch
from diffusers import AmusedPipeline

# Assuming the rest of your code is unchanged and initializes the pipeline

prompt = title
negative_prompt = "low quality, ugly"
pipe = AmusedPipeline.from_pretrained(
    "amused/amused-512", variant="fp16", torch_dtype=torch.float16
)
pipe = pipe.to("cuda")
# Generate the image
image = pipe(prompt, negative_prompt=negative_prompt, generator=torch.manual_seed(0)).images[0]

# Save the image to a file
image_path = "generated_image.png"  # Specify the path and file name here
image.save(image_path)

print(f"Image saved to {image_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/135 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/574 [00:00<?, ?B/s]
# transformer/config.json:   0%|          | 0.00/676 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# model.fp16.safetensors:   0%|          | 0.00/247M [00:00<?, ?B/s]
# vqvae/config.json:   0%|          | 0.00/804 [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/293M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/12 [00:00<?, ?it/s]
# Image saved to generated_image.png

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter
from PIL import Image

# Path to your image and output PDF
image_path = 'generated_image.png'  # Ensure this is the correct path to your image
output_pdf = 'title_page.pdf'


# Open the image to get its size for resizing purposes
img = Image.open(image_path)
img_width, img_height = img.size

# Calculate the PDF page size in pixels (converting from points: 1 point = 1/72 inch)
pdf_width, pdf_height = letter  # in points
scale_w = pdf_width / img_width
scale_h = pdf_height / img_height
scale = min(scale_w, scale_h)

# Create a new canvas and draw the image
c = canvas.Canvas(output_pdf, pagesize=letter)
c.drawImage(image_path, 0, 0, width=pdf_width, height=pdf_height, preserveAspectRatio=True, mask='auto')

# Add the title text on top of the image
c.setFont("Helvetica", 26)  # Using a default font
c.drawCentredString(pdf_width / 2, pdf_height - 50, title)  # Adjust positioning as needed

# Save the PDF
c.save()

print(f"PDF saved as {output_pdf}")
# Out:
# PDF saved as title_page.pdf

# %%
import PyPDF2

# File paths
title_path = 'title_page.pdf'
ebook_file_path = 'merged_ebook.pdf'
merged_file_path = 'merged_ebook_final.pdf'

# Open the PDF files
with open(title_path, 'rb') as contents_file, open(ebook_file_path, 'rb') as ebook_file:
    # Create PDF reader objects for each file
    contents_reader = PyPDF2.PdfReader(contents_file)
    ebook_reader = PyPDF2.PdfReader(ebook_file)

    # Create a PDF writer object for the output file
    pdf_writer = PyPDF2.PdfWriter()

    # Add all pages from the contents PDF
    for page_num in range(len(contents_reader.pages)):
        page = contents_reader.pages[page_num]
        pdf_writer.add_page(page)

    # Add all pages from the ebook PDF
    for page_num in range(len(ebook_reader.pages)):
        page = ebook_reader.pages[page_num]
        pdf_writer.add_page(page)

    # Write to a new PDF file
    with open(merged_file_path, 'wb') as merged_file:
        pdf_writer.write(merged_file)

print(f'PDF files have been merged into {merged_file_path}')
# Out:
# PDF files have been merged into deliverable.pdf
